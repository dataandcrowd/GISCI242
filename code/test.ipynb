# %%
import geopandas as gpd

url = 'https://raw.githubusercontent.com/jcanalesluna/bcn-geodata/master/districtes/districtes.geojson'

districts = gpd.read_file(url)

districts
#print(districts)

print(districts.crs)

districts['area'] = districts.area / 1000000

districts

## Visualisation
ax= districts.plot(figsize=(10,6))
# Out:
# EPSG:4326
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_11416\1045260086.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   districts['area'] = districts.area / 1000000
